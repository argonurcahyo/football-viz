# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains

from webdriver_manager.chrome import ChromeDriverManager

import pandas as pd
import time

options = Options()
options.headless = False

driver = webdriver.Chrome(options=options,service=ChromeService(ChromeDriverManager().install()))
# Out:
# [WDM] - Downloading: 100%|██████████| 6.29M/6.29M [00:01<00:00, 6.58MB/s]

# %%
zz_url = 'https://www.brazzers.com/videos/page/1'

# %%
driver.get(zz_url)

scenediv = driver.find_elements(By.CSS_SELECTOR,'.e1vusg2z1 .e1jyqorn29')

# %%
action = ActionChains(driver)
hover_thumb = scenediv[0].find_element(By.CSS_SELECTOR,'.eh7jk9w0')
action.move_to_element(hover_thumb).perform()
time.sleep(5)
hover_thumb.get_attribute('innerHTML')
preview_url = hover_thumb.find_element(By.CSS_SELECTOR,'video').get_attribute('src')
preview_url
# Out:
# 'https://prog-public-ht.project1content.com/e1a/17b/2db/310/44e/eb6/118/5e1/33f/84a/36/mediabook/mediabook_320p.mp4'

# %%
scene_title = scenediv[0].find_element(By.CSS_SELECTOR,'.e1qkfw3j0 a').get_attribute('title')
scene_url = scenediv[0].find_element(By.CSS_SELECTOR,'.e1qkfw3j0 a').get_attribute('href')
scene_id = scene_url.split('/')[4]
scene_img = scenediv[0].find_element(By.CSS_SELECTOR,'a picture img').get_attribute('src')
scene_performer = scenediv[0].find_element(By.CSS_SELECTOR,'.e1jyqorn17 .e1jyqorn11').text
scene_date = scenediv[0].find_element(By.CSS_SELECTOR,'.e1jyqorn17 .e1jyqorn24').text
scene_date
# Out:
# 'Oct 20, 2022'

# %%
def get_scenes_by_page(driver, page=1):
    zz_url = f'https://www.brazzers.com/videos/page/{page}'
    zz_scenes_details = pd.DataFrame()
    data = []

    driver.get(zz_url)
    scenediv = driver.find_elements(By.CSS_SELECTOR, '.e1vusg2z1 .e1jyqorn29')

    for i in range(len(scenediv)):
        # hover thumbnail
        action = ActionChains(driver)
        hover_thumb = scenediv[i].find_element(By.CSS_SELECTOR, '.eh7jk9w0')
        action.move_to_element(hover_thumb).perform()
        time.sleep(1)

        try:
            preview_url = hover_thumb.find_element(
                By.CSS_SELECTOR, 'video').get_attribute('src')
        except:
            preview_url = None
        try:
            scene_title = scenediv[i].find_element(
                By.CSS_SELECTOR, '.e1qkfw3j0 a').get_attribute('title')
        except:
            scene_title = None
        try:
            scene_url = scenediv[i].find_element(
                By.CSS_SELECTOR, '.e1qkfw3j0 a').get_attribute('href')
        except:
            scene_url = None
        try:
            scene_id = scene_url.split('/')[4]
        except:
            scene_id = None
        try:
            scene_img = scenediv[i].find_element(
                By.CSS_SELECTOR, 'a picture img').get_attribute('src')
        except:
            scene_img = None
        try:
            scene_performer = scenediv[i].find_element(
                By.CSS_SELECTOR, '.e1jyqorn17 .e1jyqorn11').text
        except:
            scene_performer = None
        try:
            scene_date = scenediv[i].find_element(
                By.CSS_SELECTOR, '.e1jyqorn17 .e1jyqorn24').text
        except:
            scene_date = None
        
        print(f'{page}|{i+1:02}. {scene_title}')

        scene_detail = {
            'id': scene_id,
            'title': scene_title,
            'performer': scene_performer,
            'release_date': scene_date,
            'url': scene_url,
            'img_url': scene_img,
            'preview_url': preview_url
        }
        data.append(scene_detail)
    zz_scenes_details = pd.DataFrame(data)
    return zz_scenes_details

# %%
scenes_df = pd.DataFrame()
for page in range(1,11):
    d = get_scenes_by_page(driver,page)
    scenes_df = pd.concat([scenes_df, d]).reset_index(drop=True)
# Out:
# 1|01. Sneaking Around With The Sister-In-Law
# 1|02. Sugar Daddy vs Boyfriend
# 1|03. Fucking In The Sun
# 1|04. Lick My Stepmom
# 1|05. Fanfriction: Part 1
# 1|06. Scissoring The Sweaty Slut
# 1|07. Working Girls
# 1|08. Impress The Boss
# 1|09. Front Row Seat to Cuckold Sex
# 1|10. Slither
# 1|11. Soaking Up Kitana
# 1|12. Pervy Discipline
# 1|13. All's Fair in Love And Prank War
# 1|14. Meeting & Eating My Dad's New Girlfriend
# 1|15. Step Sibling Rivalry, Threesome Gloryhole Fuckery
# 1|16. Big Wet Office Fantasy
# 1|17. Hitching a Ride
# 1|18. Two Oiled MILFs Share a Cock
# 1|19. Mother Daughter Double Hitter: Part 2﻿﻿
# 1|20. Mother Daughter Double Hitter: Part 1
# 1|21. Don't Let Her Out
# 1|22. Bougie Babe & The Cheating Rude Boy
# 1|23. Sign Me Up For Sex
# 1|24. Playing Doubles
# 2|01. Juicy Jae On Display
# 2|02. A Course in Creampies
# 2|03. Cleaning Up Before A Filthy Fuck
# 2|04. MILF Does The Body Good
# 2|05. Gagging On The Guru
# 2|06. A Perfect Storm
# 2|07. Alexxa's Double Penetration Vice
# 2|08. Bodega Bro Unlocks Impossible Achievement
# 2|09. Bound For Him
# 2|10. Fucking GF's Dildo-Loving Roommates
# 2|11. Scream Her Name
# 2|12. Stepmom's Bath Turns into a Threesome Smash
# 2|13. Massage Cheat Caught & Dominated
# 2|14. Anal Evaluation
# 2|15. Detention For My Teacher
# 2|16. Horny Realtor's Revenge
# 2|17. Tae Time
# 2|18. Cum Dodger's Depot
# 2|19. Waiting On My Ex
# 2|20. Oiling Up Their Big Naturals
# 2|21. Slutty Stalker Secretary
# 2|22. My Bro’s Geeky GF Does Anal!
# 2|23. 2 Squirting Wives Seduce the Pool Guy
# 2|24. Imaginary Fuck Friend
# 3|01. Everything Must Go!
# 3|02. Horny Sex Goddesses
# 3|03. Shoe Shop Til Dick Drops
# 3|04. BrideZZilla: A Fuckfest At The Wedding part 3
# 3|05. School Of Cock
# 3|06. BrideZZilla: A Fuckfest At The Wedding part 2
# 3|07. BrideZZilla: A Fuckfest At The Wedding part 1
# 3|08. Direct-2-Face Vabbing Squats
# 3|09. A Peg On The Corporate Ladder
# 3|10. Lola's Fuckable Feet
# 3|11. Put That Pussy On Ice
# 3|12. Lending A Horny Hand
# 3|13. The Devil Wears Nada
# 3|14. Slippery When Wet MILF Bangs Stepson
# 3|15. So Much Oil She Shines!
# 3|16. Fucked From The Future
# 3|17. Climb In Her Window, Cum In Her Mouth
# 3|18. Angela's Airtight DP
# 3|19. Mother In Law Knows Best
# 3|20. Warning: Shoplifters Will Be Pro-ASS-ecuted
# 3|21. Skirt Pervert
# 3|22. Luna Star: The Girlfriend Experience
# 3|23. Laying The Landlord
# 3|24. Massage Me, Fuck Me, And Ignore Her
# 4|01. Banging the Businesswoman
# 4|02. Work That Pussy
# 4|03. Good Cock, Bad Cop
# 4|04. Tongue Tied & Pussy-Whipped
# 4|05. A+ Foursome Fuck
# 4|06. Get Your Ass Out Of My Shot
# 4|07. Blindfolding Him for Her DP
# 4|08. Bubbly Fucking
# 4|09. Bank Banging Fools Sloppy Robber
# 4|10. Precious Pussy, Open Throat
# 4|11. Break-Up Cuck
# 4|12. Thirst Trap
# 4|13. Fucking My GF's Tall Lookalike Roomie
# 4|14. Anal Angel Next Door
# 4|15. Waiter Gets Served a Big Round Ass
# 4|16. An Extramarital Affair
# 4|17. I Wanna Fuck Your Mom
# 4|18. Lulu's POV Fantasy
# 4|19. Pussy Talk
# 4|20. Horny Couple Pranks And Fucks
# 4|21. Hacking Your Cock
# 4|22. Trouser Arouser
# 4|23. The Plumber's Cumming
# 4|24. Greasy Diner Anal Escapade
# 5|01. Pussy Freak On A Leash
# 5|02. Cheeky Cheaters
# 5|03. Good Neighbors
# 5|04. Bathtub Anal With A MILF
# 5|05. Freeuse Getaway: Part 3
# 5|06. Devoured
# 5|07. Freeuse Getaway: Part 2
# 5|08. An Anniversary Surprise
# 5|09. Freeuse Getaway: Part 1
# 5|10. A Modern Romance - Latin Lovers' Anal Treachery
# 5|11. Raunchy Realtor Gets Fucked Part 1
# 5|12. Raunchy Realtor Gets Fucked Part 2
# 5|13. This Thing of Ours
# 5|14. Welcome To White's Ward 3
# 5|15. Sit On My Strap-on And Spin
# 5|16. Welcome To White's Ward - Part 2
# 5|17. The Deepthroat Doctor Is In
# 5|18. Welcome To White's Ward - Part 1
# 5|19. Rubbing Jexxxica The Right Way
# 5|20. Pervy Roommate's VR Titty Squeeze
# 5|21. The Missing Ingredient
# 5|22. The Gauntlet
# 5|23. Nicole's Heavenly Booty
# 5|24. Garage Banned
# 6|01. Garage Banned
# 6|02. My Boss's New Boobs
# 6|03. Taught To Be Naughty
# 6|04. Two Loads Are Better Than None
# 6|05. Deepthroat Challenge
# 6|06. Double Vaginal Degenerates
# 6|07. The Money Shot
# 6|08. Sneaky Masseur Likes Big Tits
# 6|09. Kagney Gets Ready For Cock
# 6|10. My GF's Hot Mom Does Anal!
# 6|11. Frenemies Who Fuck
# 6|12. Curious Besties Raunchy Resort
# 6|13. Milk Tank Mixup
# 6|14. Underwater Handjob
# 6|15. Toilet-Stuck Slut Gets Double Dicked
# 6|16. Anal With The Sneaky, Horny Wife
# 6|17. Spying On Roomie's GF With XXX-Ray Glasses
# 6|18. Filling All Of Armani's Flexible Holes
# 6|19. Stacked In Stockings
# 6|20. Condom Suckin' Tongue Lickin' Dirty MILF Threesome
# 6|21. The Surrogate
# 6|22. Virtual Fuckfest
# 6|23. Cheeky Lesbians Steal Roommate's Toy For Ass Play
# 6|24. Big Natural Babe Gets The Double Dickdown She Thirsts For
# 7|01. The Deepest Fuck
# 7|02. Debauchery at the Dinner Party
# 7|03. Let Me Smell Your Dick!
# 7|04. Sneaky Shoe Seduction
# 7|05. MILF Gets Railed By Cocky Mover
# 7|06. Party Mates
# 7|07. In a Bind
# 7|08. My GF's Roommate is THICC AF!
# 7|09. Twisted Scissors
# 7|10. Don't Touch Her 9
# 7|11. Big Titty Tutorial
# 7|12. Fast Times At The Sloppy Salon
# 7|13. Wishful Inking
# 7|14. Ass Fuck The Walls Down
# 7|15. Work Me Out
# 7|16. Horny MILF Attracted To Couple Fucking
# 7|17. My Big Titty Goth Roommate
# 7|18. Sexually Rated Programming: Blowbang
# 7|19. Get Your Shine On
# 7|20. Copycat MILF Steals New Stepdaughter's BF
# 7|21. The AV Club
# 7|22. Brazzers Meets Elsie
# 7|23. Gizelle & Kendra's Oily Rubdown
# 7|24. Balls Deep In The MILF's Bubble Bath
# 8|01. The Anal Intern
# 8|02. Green With Frenzy
# 8|03. ZZ Guide to Perverted Massages
# 8|04. My Friend's Mom's Ass
# 8|05. Glasses Girls Go For It
# 8|06. Choking for my Dad's Best Friend
# 8|07. The Bride Who Fucked Them All Part 1
# 8|08. The Bride Who Fucked Them All Part 2
# 8|09. Sending Good Vibes
# 8|10. Servicing My Bossy New Stepsister
# 8|11. Sneaky Anal Massage
# 8|12. VR MILF DTF
# 8|13. The Mating Game: Part 2
# 8|14. Watch This Trick, Inflatable Tits!
# 8|15. Catch Some ZZ's
# 8|16. The Mating Game: Part 1
# 8|17. Lunch with The Steps
# 8|18. Harnessing Rachel
# 8|19. Suzy's Deep Massage
# 8|20. Prankster Gets a Pussy Sandwich
# 8|21. Fix It Or Fuck Me, Nerd
# 8|22. Abinator 3000
# 8|23. Park And Anal Play
# 8|24. Living With Influencers
# 9|01. Cheating Gamer Distracted by Huge Cock
# 9|02. Big Naturals Get Soaked
# 9|03. Outgoing Call, Incoming Cock
# 9|04. Fucked For The Last Time
# 9|05. Fucking Tension
# 9|06. Oiled Minx Named Lynx
# 9|07. Twinz 4 The Win
# 9|08. Spread Her Wide
# 9|09. Life Of A Bimbo
# 9|10. MILF Librarian is Secretly Addicted to Eating Cum
# 9|11. MILF's Party Streakers Threesome
# 9|12. No Look, All Touch
# 9|13. Dick Riding Buttcamp
# 9|14. Nasty Old Bench Flasher Meets Thirsty Jogging Nymph
# 9|15. Fit Fixation Fix
# 9|16. Squirt, Shout, Let It All Out!
# 9|17. There's Plenty To Go Around!
# 9|18. Muff Diving At The Mechanics
# 9|19. Scissor Happy Slut Gets MILF Threesome
# 9|20. Single Horny Female
# 9|21. Awakening Deville
# 9|22. Massaging Your Hubby's Cock
# 9|23. Eye On Her Thigh Strap-On
# 9|24. Our Son's Girlfriend 2
# 10|01. Call of Booty
# 10|02. Dunkin' On The Neighborhood MILF & Lesbian's 1st Cock
# 10|03. This One Time at Band Camp
# 10|04. Sucking Off The Salesman
# 10|05. Inked
# 10|06. Double Double Oil and Trouble
# 10|07. Trending So Hard RN
# 10|08. Dominuru
# 10|09. Two Lusty Women
# 10|10. Sinntillating Curves
# 10|11. Sneaky Wife Craves Cock, Not Pie
# 10|12. Bone Cracking Fornication
# 10|13. Rubbing The Robber's Dick
# 10|14. The Key To Her Heart Is In Her Ass
# 10|15. Badder Than He Thinks
# 10|16. Lovestruck
# 10|17. Luxury Girl's Webcam Cock Ride
# 10|18. Cosplay MILF Creeps On Couple
# 10|19. Tied, Tickled & Vibed! Part II
# 10|20. Tied, Tickled & Vibed! Part I
# 10|21. Tossing My Roommate's Salad
# 10|22. The Clumsy Intern
# 10|23. Glamping Gloryhole DILF-Hunter Duo
# 10|24. Anything For An A

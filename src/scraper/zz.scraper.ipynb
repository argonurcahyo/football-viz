# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains

from webdriver_manager.chrome import ChromeDriverManager

import pandas as pd
import time

options = Options()
options.headless = False

driver = webdriver.Chrome(options=options,service=ChromeService(ChromeDriverManager().install()))

# %%
zz_url = 'https://www.brazzers.com/videos/page/1'

# %%
driver.get(zz_url)

scenediv = driver.find_elements(By.CSS_SELECTOR,'.e1vusg2z1 .e1jyqorn29')

# %%
action = ActionChains(driver)
hover_thumb = scenediv[0].find_element(By.CSS_SELECTOR,'.eh7jk9w0')
action.move_to_element(hover_thumb).perform()
time.sleep(5)
hover_thumb.get_attribute('innerHTML')
preview_url = hover_thumb.find_element(By.CSS_SELECTOR,'video').get_attribute('src')
preview_url
# Out:
# 'https://prog-public-ht.project1content.com/65b/309/578/62b/4ca/e82/268/0e4/b0e/0c2/9f/mediabook/mediabook_320p.mp4'

# %%
scene_title = scenediv[0].find_element(By.CSS_SELECTOR,'.e1qkfw3j0 a').get_attribute('title')
scene_url = scenediv[0].find_element(By.CSS_SELECTOR,'.e1qkfw3j0 a').get_attribute('href')
scene_id = scene_url.split('/')[4]
scene_img = scenediv[0].find_element(By.CSS_SELECTOR,'a picture img').get_attribute('src')
scene_performer = scenediv[0].find_element(By.CSS_SELECTOR,'.e1jyqorn17 .e1jyqorn11').text
scene_date = scenediv[0].find_element(By.CSS_SELECTOR,'.e1jyqorn17 .e1jyqorn24').text
scene_date
# Out:
# 'Oct 20, 2022'

# %%
def get_scenes_by_page(driver, page=1):
    zz_url = f'https://www.brazzers.com/videos/page/{page}'
    zz_scenes_details = pd.DataFrame()
    data = []

    driver.get(zz_url)
    time.sleep(10)
    scenediv = driver.find_elements(
        By.CSS_SELECTOR, '.e1vusg2z1 .e1jyqorn29')

    for i in range(len(scenediv)):
        # hover thumbnail
        action = ActionChains(driver)
        hover_thumb = scenediv[i].find_element(
            By.CSS_SELECTOR, '.eh7jk9w0')
        action.move_to_element(hover_thumb).perform()
        time.sleep(1)

        try:
            preview_url = hover_thumb.find_element(
                By.CSS_SELECTOR, 'video').get_attribute('src')
        except:
            preview_url = None
        try:
            scene_title = scenediv[i].find_element(
                By.CSS_SELECTOR, '.e1qkfw3j0 a').get_attribute('title')
        except:
            scene_title = None
        try:
            scene_url = scenediv[i].find_element(
                By.CSS_SELECTOR, '.e1qkfw3j0 a').get_attribute('href')
        except:
            scene_url = None
        try:
            scene_id = scene_url.split('/')[4]
        except:
            scene_id = None
        try:
            scene_img = scenediv[i].find_element(
                By.CSS_SELECTOR, 'a picture img').get_attribute('src')
        except:
            scene_img = None
        try:
            scene_performer = scenediv[i].find_element(
                By.CSS_SELECTOR, '.e1jyqorn17 .e1jyqorn11').text
        except:
            scene_performer = None
        try:
            scene_date = scenediv[i].find_element(
                By.CSS_SELECTOR, '.e1jyqorn17 .e1jyqorn24').text
        except:
            scene_date = None

        print(f'{page}|{i+1:02}. {scene_title}')

        scene_detail = {
            'id': scene_id,
            'title': scene_title,
            'performer': scene_performer,
            'release_date': scene_date,
            'url': scene_url,
            'img_url': scene_img,
            'preview_url': preview_url
        }
        data.append(scene_detail)

    zz_scenes_details = pd.DataFrame(data)
    return zz_scenes_details

# %%
scenes_df = pd.DataFrame()
for page in range(1, 11):
    d = get_scenes_by_page(driver, page)
    scenes_df = pd.concat([scenes_df, d]).reset_index(drop=True)
# Out:
# 1|01. GrandPervs 1
# 1|02. Hot and Oiled Up, Ready to Fuck
# 1|03. Pussy Locked And Dick Loaded
# 1|04. Fanfriction: Part 2
# 1|05. Follow Me For A Fuck
# 1|06. My Bro’s Ho Gots Nice Toes
# 1|07. Hot MILF, Party Crasher
# 1|08. Fucking Her Office Rival
# 1|09. Freeuse Yoga And Shower Fuck
# 1|10. Jennifer Gets Wet
# 1|11. Sneaking Around With The Sister-In-Law
# 1|12. Sugar Daddy vs Boyfriend
# 1|13. Fucking In The Sun
# 1|14. Lick My Stepmom
# 1|15. Fanfriction: Part 1
# 1|16. Scissoring The Sweaty Slut
# 1|17. Working Girls
# 1|18. Impress The Boss
# 1|19. Front Row Seat to Cuckold Sex
# 1|20. Slither
# 1|21. Soaking Up Kitana
# 1|22. Pervy Discipline
# 1|23. Meeting & Eating My Dad's New Girlfriend
# 1|24. All's Fair in Love And Prank War
# 2|01. Big Wet Office Fantasy
# 2|02. Step Sibling Rivalry, Threesome Gloryhole Fuckery
# 2|03. Hitching a Ride
# 2|04. Two Oiled MILFs Share a Cock
# 2|05. Mother Daughter Double Hitter: Part 2﻿﻿
# 2|06. Mother Daughter Double Hitter: Part 1
# 2|07. Don't Let Her Out
# 2|08. Bougie Babe & The Cheating Rude Boy
# 2|09. Sign Me Up For Sex
# 2|10. Playing Doubles
# 2|11. Juicy Jae On Display
# 2|12. A Course in Creampies
# 2|13. Cleaning Up Before A Filthy Fuck
# 2|14. MILF Does The Body Good
# 2|15. A Perfect Storm
# 2|16. Gagging On The Guru
# 2|17. Alexxa's Double Penetration Vice
# 2|18. Bodega Bro Unlocks Impossible Achievement
# 2|19. Bound For Him
# 2|20. Fucking GF's Dildo-Loving Roommates
# 2|21. Scream Her Name
# 2|22. Stepmom's Bath Turns into a Threesome Smash
# 2|23. Anal Evaluation
# 2|24. Massage Cheat Caught & Dominated
# 3|01. Detention For My Teacher
# 3|02. Horny Realtor's Revenge
# 3|03. Tae Time
# 3|04. Cum Dodger's Depot
# 3|05. Waiting On My Ex
# 3|06. Oiling Up Their Big Naturals
# 3|07. Slutty Stalker Secretary
# 3|08. My Bro’s Geeky GF Does Anal!
# 3|09. Imaginary Fuck Friend
# 3|10. 2 Squirting Wives Seduce the Pool Guy
# 3|11. Everything Must Go!
# 3|12. Horny Sex Goddesses
# 3|13. Shoe Shop Til Dick Drops
# 3|14. BrideZZilla: A Fuckfest At The Wedding part 3
# 3|15. BrideZZilla: A Fuckfest At The Wedding part 2
# 3|16. School Of Cock
# 3|17. Direct-2-Face Vabbing Squats
# 3|18. BrideZZilla: A Fuckfest At The Wedding part 1
# 3|19. A Peg On The Corporate Ladder
# 3|20. Lola's Fuckable Feet
# 3|21. Put That Pussy On Ice
# 3|22. Lending A Horny Hand
# 3|23. Slippery When Wet MILF Bangs Stepson
# 3|24. The Devil Wears Nada
# 4|01. So Much Oil She Shines!
# 4|02. Fucked From The Future
# 4|03. Climb In Her Window, Cum In Her Mouth
# 4|04. Angela's Airtight DP
# 4|05. Mother In Law Knows Best
# 4|06. Warning: Shoplifters Will Be Pro-ASS-ecuted
# 4|07. Skirt Pervert
# 4|08. Luna Star: The Girlfriend Experience
# 4|09. Laying The Landlord
# 4|10. Massage Me, Fuck Me, And Ignore Her
# 4|11. Banging the Businesswoman
# 4|12. Work That Pussy
# 4|13. Tongue Tied & Pussy-Whipped
# 4|14. Good Cock, Bad Cop
# 4|15. Get Your Ass Out Of My Shot
# 4|16. A+ Foursome Fuck
# 4|17. Blindfolding Him for Her DP
# 4|18. Bubbly Fucking
# 4|19. Bank Banging Fools Sloppy Robber
# 4|20. Precious Pussy, Open Throat
# 4|21. Break-Up Cuck
# 4|22. Thirst Trap
# 4|23. Fucking My GF's Tall Lookalike Roomie
# 4|24. Anal Angel Next Door
# 5|01. An Extramarital Affair
# 5|02. Waiter Gets Served a Big Round Ass
# 5|03. I Wanna Fuck Your Mom
# 5|04. Lulu's POV Fantasy
# 5|05. Pussy Talk
# 5|06. Horny Couple Pranks And Fucks
# 5|07. Hacking Your Cock
# 5|08. Trouser Arouser
# 5|09. The Plumber's Cumming
# 5|10. Greasy Diner Anal Escapade
# 5|11. Pussy Freak On A Leash
# 5|12. Cheeky Cheaters
# 5|13. Bathtub Anal With A MILF
# 5|14. Good Neighbors
# 5|15. Devoured
# 5|16. Freeuse Getaway: Part 3
# 5|17. Freeuse Getaway: Part 2
# 5|18. An Anniversary Surprise
# 5|19. Freeuse Getaway: Part 1
# 5|20. A Modern Romance - Latin Lovers' Anal Treachery
# 5|21. Raunchy Realtor Gets Fucked Part 1
# 5|22. Raunchy Realtor Gets Fucked Part 2
# 5|23. This Thing of Ours
# 5|24. Welcome To White's Ward 3
# 6|01. Sit On My Strap-on And Spin
# 6|02. Welcome To White's Ward - Part 2
# 6|03. The Deepthroat Doctor Is In
# 6|04. Welcome To White's Ward - Part 1
# 6|05. Rubbing Jexxxica The Right Way
# 6|06. Pervy Roommate's VR Titty Squeeze
# 6|07. The Gauntlet
# 6|08. The Missing Ingredient
# 6|09. Nicole's Heavenly Booty
# 6|10. Classy Suburban Wife's Cum Obsession
# 6|11. Garage Banned
# 6|12. Taught To Be Naughty
# 6|13. My Boss's New Boobs
# 6|14. Deepthroat Challenge
# 6|15. Two Loads Are Better Than None
# 6|16. Double Vaginal Degenerates
# 6|17. The Money Shot
# 6|18. Sneaky Masseur Likes Big Tits
# 6|19. Kagney Gets Ready For Cock
# 6|20. My GF's Hot Mom Does Anal!
# 6|21. Curious Besties Raunchy Resort
# 6|22. Frenemies Who Fuck
# 6|23. Underwater Handjob
# 6|24. Milk Tank Mixup
# 7|01. Anal With The Sneaky, Horny Wife
# 7|02. Toilet-Stuck Slut Gets Double Dicked
# 7|03. Filling All Of Armani's Flexible Holes
# 7|04. Spying On Roomie's GF With XXX-Ray Glasses
# 7|05. Stacked In Stockings
# 7|06. Condom Suckin' Tongue Lickin' Dirty MILF Threesome
# 7|07. The Surrogate
# 7|08. Virtual Fuckfest
# 7|09. Cheeky Lesbians Steal Roommate's Toy For Ass Play
# 7|10. Big Natural Babe Gets The Double Dickdown She Thirsts For
# 7|11. The Deepest Fuck
# 7|12. Debauchery at the Dinner Party
# 7|13. Sneaky Shoe Seduction
# 7|14. Let Me Smell Your Dick!
# 7|15. MILF Gets Railed By Cocky Mover
# 7|16. Party Mates
# 7|17. In a Bind
# 7|18. My GF's Roommate is THICC AF!
# 7|19. Twisted Scissors
# 7|20. Don't Touch Her 9
# 7|21. Big Titty Tutorial
# 7|22. Fast Times At The Sloppy Salon
# 7|23. Ass Fuck The Walls Down
# 7|24. Wishful Inking
# 8|01. Horny MILF Attracted To Couple Fucking
# 8|02. Work Me Out
# 8|03. My Big Titty Goth Roommate
# 8|04. Sexually Rated Programming: Blowbang
# 8|05. Get Your Shine On
# 8|06. Copycat MILF Steals New Stepdaughter's BF
# 8|07. Brazzers Meets Elsie
# 8|08. The AV Club
# 8|09. Gizelle & Kendra's Oily Rubdown
# 8|10. Balls Deep In The MILF's Bubble Bath
# 8|11. Green With Frenzy
# 8|12. The Anal Intern
# 8|13. ZZ Guide to Perverted Massages
# 8|14. My Friend's Mom's Ass
# 8|15. Choking for my Dad's Best Friend
# 8|16. Glasses Girls Go For It
# 8|17. The Bride Who Fucked Them All Part 1
# 8|18. The Bride Who Fucked Them All Part 2
# 8|19. Sending Good Vibes
# 8|20. Servicing My Bossy New Stepsister
# 8|21. Sneaky Anal Massage
# 8|22. VR MILF DTF
# 8|23. Watch This Trick, Inflatable Tits!
# 8|24. The Mating Game: Part 2
# 9|01. The Mating Game: Part 1
# 9|02. Catch Some ZZ's
# 9|03. Harnessing Rachel
# 9|04. Lunch with The Steps
# 9|05. Suzy's Deep Massage
# 9|06. Prankster Gets a Pussy Sandwich
# 9|07. Fix It Or Fuck Me, Nerd
# 9|08. Abinator 3000
# 9|09. Park And Anal Play
# 9|10. Living With Influencers
# 9|11. Cheating Gamer Distracted by Huge Cock
# 9|12. Big Naturals Get Soaked
# 9|13. Fucked For The Last Time
# 9|14. Outgoing Call, Incoming Cock
# 9|15. Fucking Tension
# 9|16. Oiled Minx Named Lynx
# 9|17. Spread Her Wide
# 9|18. Twinz 4 The Win
# 9|19. Life Of A Bimbo
# 9|20. MILF Librarian is Secretly Addicted to Eating Cum
# 9|21. MILF's Party Streakers Threesome
# 9|22. No Look, All Touch
# 9|23. Dick Riding Buttcamp
# 9|24. Nasty Old Bench Flasher Meets Thirsty Jogging Nymph
# 10|01. Fit Fixation Fix
# 10|02. Squirt, Shout, Let It All Out!
# 10|03. Muff Diving At The Mechanics
# 10|04. There's Plenty To Go Around!
# 10|05. Single Horny Female
# 10|06. Scissor Happy Slut Gets MILF Threesome
# 10|07. Awakening Deville
# 10|08. Massaging Your Hubby's Cock
# 10|09. Eye On Her Thigh Strap-On
# 10|10. Our Son's Girlfriend 2
# 10|11. Call of Booty
# 10|12. Dunkin' On The Neighborhood MILF & Lesbian's 1st Cock
# 10|13. This One Time at Band Camp
# 10|14. Sucking Off The Salesman
# 10|15. Inked
# 10|16. Double Double Oil and Trouble
# 10|17. Trending So Hard RN
# 10|18. Dominuru
# 10|19. Two Lusty Women
# 10|20. Sinntillating Curves
# 10|21. Sneaky Wife Craves Cock, Not Pie
# 10|22. Bone Cracking Fornication
# 10|23. The Key To Her Heart Is In Her Ass
# 10|24. Rubbing The Robber's Dick

# %%
scenes_df.to_csv('../../data/zz10.csv')

# %%
import pandas as pd

# %%
wc2014 = pd.read_excel('../../../data/WC.xlsx',
                       sheet_name='WC2014', index_col=0)
wc2018 = pd.read_excel('../../../data/WC.xlsx',
                       sheet_name='WC2018', index_col=0)
wc2022 = pd.read_excel('../../../data/WC.xlsx',
                       sheet_name='WC2022', index_col=0)

# %%
wc2022[['country', 'group']].merge(
    wc2018[['country', 'group']], on='country', how='outer').merge(
        wc2014[['country', 'group']], on='country', how='outer')
# Out:
#                    country group_x group_y group
# 0                  Ecuador       A     NaN     E
# 1              Netherlands       A     NaN     B
# 2                    Qatar       A     NaN   NaN
# 3                  Senegal       A       H   NaN
# 4                  England       B       G     D
# 5                     Iran       B       B     F
# 6            United States       B     NaN     G
# 7                    Wales       B     NaN   NaN
# 8                Argentina       C       D     F
# 9                   Mexico       C       F     A
# 10                  Poland       C       H   NaN
# 11            Saudi Arabia       C       A   NaN
# 12               Australia       D       C     B
# 13                 Denmark       D       C   NaN
# 14                  France       D       C     E
# 15                 Tunisia       D       G   NaN
# 16              Costa Rica       E       E     D
# 17                 Germany       E       F     G
# ...

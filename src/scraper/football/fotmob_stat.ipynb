# %%
import urllib.request, json
import pandas as pd

# %%
matchlist = pd.read_csv('../../../data/epl_matches_2223.csv')
url = f'https://www.fotmob.com/api/matchDetails?matchId=4010215'
with urllib.request.urlopen(url) as req:
    data = json.load(req)
    print(data)
# Out:
# {'general': {'matchId': '4010215', 'matchName': 'Real Madrid-vs-Celtic_Wed, Nov 2, 2022, 17:45 UTC', 'matchRound': '6', 'teamColors': {'home': '#085098', 'away': '#007838'}, 'leagueId': 879538, 'leagueName': 'Champions League Grp. F', 'leagueRoundName': 'Champions League Grp. F Round 6', 'parentLeagueId': 42, 'countryCode': 'INT-2', 'parentLeagueName': 'Champions League', 'parentLeagueSeason': '2022/2023', 'homeTeam': {'name': 'Real Madrid', 'id': 8633}, 'awayTeam': {'name': 'Celtic', 'id': 9925}, 'matchTimeUTC': 'Wed, Nov 2, 2022, 17:45 UTC', 'matchTimeUTCDate': '2022-11-02T17:45:00.000Z', 'started': True, 'finished': True}, 'header': {'teams': [{'name': 'Real Madrid', 'id': 8633, 'score': 5, 'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/8633_small.png', 'pageUrl': '/teams/8633/overview/real-madrid', 'fifaRank': None}, {'name': 'Celtic', 'id': 9925, 'score': 1, 'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/9925_small.png', 'pageUrl': '/t
# ...

# %%
data.keys()
# Out:
# dict_keys(['general', 'header', 'nav', 'ongoing', 'hasPendingVAR', 'content', 'seo'])
